# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th{border: 1px
# black solid ! important;color:black !important;}
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th{border: 1px
# black solid ! important;color:black !important;}

# %%
import ipywidgets as widgets
from traitlets import Unicode, Int, validate
class MolSVGWidget(widgets.DOMWidget):
    _view_name = Unicode('MolSVGView').tag(sync=True)
    _view_module = Unicode('molsvg_widget').tag(sync=True)
    _view_module_version = Unicode('0.0.1').tag(sync=True)
     
    svg = Unicode('', help="svg to be rendered").tag(sync=True)
    #selected_atoms = Unicode('', help="list of currently selected atoms").tag(sync=True)
    clicked_atom_idx = Unicode('', help="The index of the atom that was just clicked").tag(sync=True)

# %%
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from IPython.display import SVG
IPythonConsole.ipython_useSVG=True

# %%
def mol_with_atom_index(mol):
    for atom in mol.GetAtoms():
        atom.SetAtomMapNum(atom.GetIdx())
    return mol

# %%
def mol_to_svg(mol):
    d = Draw.MolDraw2DSVG(350, 200)
    d.SetFontSize(0.8)
    d.DrawMolecule(mol)
    d.TagAtoms(mol)
    d.FinishDrawing()
    return d.GetDrawingText()

# %%
mol = Chem.MolFromSmiles("C1CC2=C3C(=CC=C2)C\
(=CN3C1)[C@H]4[C@@H](C(=O)NC4=O)C5=CNC6=CC=CC=C65")
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(mol)
d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
di = Chem.MolFromSmiles(
    'O=C(O)Cc1ccccc1Nc1c(Cl)cccc1Cl')
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(di)
d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
moi=mol_with_atom_index(mol)
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(moi);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
m = Chem.MolFromSmiles('c1ncncc1C(=O)[O-]')
m2 = Chem.Mol(m)

# %%
m = Chem.MolFromSmiles('C[C@H](F)C\C=C/O')
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(m);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
ms = [Chem.MolFromSmiles(x) for x in (
'Cc1onc(-c2ccccc2)c1C(=O)N[C@@H]1C(=O)N2[C@@H]\
(C(=O)O)C(C)(C)S[C@H]12','CC1(C)SC2C(NC(=O)\
Cc3ccccc3)C(=O)N2C1C(=O)O.[Na]')]
Draw.MolsToGridImage(ms)

# %%
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
IPythonConsole.drawOptions.useBWAtomPalette()
Draw.MolsToGridImage(ms)

# %%
m = Chem.MolFromSmiles('c1cc(C(=O)O)c(OC(=O)C)cc1')
substructure = Chem.MolFromSmarts('C(=O)O')
print(m.GetSubstructMatches(substructure))
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(m);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())
# Out:
# ((3, 4, 5), (8, 9, 7))

# %%
mol = Chem.MolFromSmiles('CN1C(=O)CN=C(C2=C1C=CC\
(=C2)Cl)C3=CC=CC=C3')
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(mol);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
def mol_with_atom_index(mol):
    for atom in mol.GetAtoms():
        atom.SetAtomMapNum(atom.GetIdx())
    return mol
mo=mol_with_atom_index(mol)
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(mo);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
ez= Chem.MolFromSmiles('C\C(F)=C\C=C(/F)\C(=C\F)\C=C')
ze=mol_with_atom_index(ez)
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(ze);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole,MolsToGridImage
mol = Chem.MolFromSmiles("O-C-C-C-C-N")
mol1 = Chem.Mol(mol)
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(mol1);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
mol1_f = Chem.FragmentOnBonds(mol1, (0, 2, 4))
d2d = rdMolDraw2D.MolDraw2DSVG(250,200)
d2d.DrawMolecule(mol1_f);d2d.FinishDrawing()
SVG(d2d.GetDrawingText())

# %%
suppl = Chem.SDMolSupplier('cdk2.sdf',removeHs=False)
ms = [x for x in suppl];len(ms)
# Out:
# 47

# %%
Draw.MolsToGridImage(ms)
