# %%
# %display latex

# %% [markdown]
# Electron :
# ![image.png](attachment:image.png)

# %%
c=299792458;w=314159265;L=2*w;B=L

# %% [markdown]
# Photon $\frac{h}{2\pi} = \hbar$ :
#
# ![image.png](attachment:image.png)
#
#
# $S = \frac{E}{c}\cdot R = \frac{h\nu}{c}\cdot \frac{c}{2\pi \nu} \Rightarrow L = \frac{h}{2\pi} = \hbar$

# %% [markdown]
#  $\omega =2\pi \nu =\frac{mc^{2}}{\hbar}\Rightarrow R=\frac{c}{\omega }=\frac{\hbar}{mc}=\lambda _{C}$

# %% [markdown]
# Electron $\frac{\hbar}{2}$ :
#
# ![image.png](attachment:image.png)
#
# $\omega =\frac{c}{\lambda _{C} }\Rightarrow L=I\cdot \omega =\frac{1}{2}mc\cdot \lambda _{C} =\frac{\hbar}{2}$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Cette image contient une erreur, il devrait y avoir un négatron(- yin), particule négative et un positron(+ yang) particule positive.

# %% [markdown]
# Ainsi, dans un système de coordonnées où l'électron est momentanément au repos, la fréquence de précession de l'axe du spin de l'électron en présence d'un champ magnétique $\vec{H}$ vaut: $\left\{\begin{matrix} \vec{\omega }=\frac{e}{m_{e}}\vec{H}\\\vec{H}=\frac{1}{c}\left [ \vec{E} \wedge \vec{v}\right ]\end{matrix}\right.\Rightarrow \vec{\omega }=\frac{e}{m_{e}c^{2}}\left [ \vec{E} \wedge \vec{v}\right ] $ Ici $\vec{v}$ désigne la vitesse de l'électron dans le repère où le noyau est au repos. L'expression précédente conduit bien à une séparation du doublet relativiste qui est deux fois supérieure à ce que l'on observe expérimentalement.

# %% [markdown]
#  Lorentz de vitesse $\vec{a}\cdot dt$, où $\vec{a} $représente l'accélération que subit l'électron suite à son mouvement rotatif autour du noyau. Dans ce nouveau repère, la fréquence de rotation s'exprime comme la somme de deux termes: $\vec{\omega }=\frac{e}{m_{e}}\vec{H}-\frac{1}{2c^{2}}\left [ \vec{v} \wedge \vec{a}\right ] $ Comme l'accélération est en première approximation proportionnelle au champ électrique, il en découle que: $\vec{a}=-\frac{e}{m_{e}}\vec{E}\Rightarrow \vec{\omega}=\frac{e}{m_{e}c^{2}}\left [ \vec{E} \wedge \vec{v}\right ]+\frac{1}{2m_{e}c^{2}}\left [ \vec{v} \wedge \vec{E}\right ]=\frac{e}{2m_{e}c^{2}}\left [ \vec{E} \wedge \vec{v}\right ]$ Ce qui est juste la moitié de l'expression où l'on considère l'électron momentanément au repos.

# %% [markdown]
# Voici maintenant un calcul montrant comment il est possible de montrer que le mouvement de rotation de l'électron sur lui-même conduit bien à un moment angulaire de spin demi-entier, sans que la vitesse en périphérie ne devienne supra-lumineuse. Soit donc $r$ la distance à l’axe de rotation où la matière constituant l'électron tourne avec une fréquence angulaire ω et une vitesse linéaire $v = r·ω$ et qui augmente donc linéairement avec $r$ comme l'avait vu Pauli. Comme dans le cadre de la théorie de la relativité $v ≤ c$, il en découle que lorsqu’on arrive en périphérie de l’électron $(r = R)$ on doit avoir, au plus, $v = c$, c'est à dire $c = R·ω$. Il en découle que l’indice de réfraction du vide pour l’onde de Broglie associé à la matière de l’électron vaut $β = v/c = r/R$:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var("y")
pc = implicit_plot(x^2+y^2-8, (x,-3,3), (y,-3,3),
plot_points=4, zorder=5)
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.9)
p2 = polygon(((0,0),(0.96,2.5),(2.5,1)),
             color="violet",alpha=0.9)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="green",alpha=0.9)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="yellow",alpha=0.5)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.9)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="salmon",alpha=1)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="lightgreen",alpha=1)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="blue",alpha=0.9)
show(pc+p1+p2+p3+p4+p5+p6+p7+p8,figsize=4,
fontsize=8,axes=False,frame=True)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
pn = polygon(((0,0),(0,1),(0.7,0.7)),
             color="cyan",alpha=0.9)
ne = polygon(((0,0),(1,0),(0.7,0.7)),
             color="violet",alpha=0.9)
so = polygon(((0,0),(-1,0),(-0.7,-0.7)),
             color="red",alpha=0.9)
ps = polygon(((0,0),(0,-1),(0.7,-0.7)),
             color="lightgreen",alpha=0.9)
sp = polygon(((0,0),(0,1),(-0.7,0.7)),
             color="green",alpha=0.9)
se = polygon(((0,0),(1,0),(0.7,-0.7)),
             color="salmon",alpha=0.5)
es = polygon(((0,0),(-1,0),(-0.7,0.7)),
             color="yellow",alpha=0.9)
sn = polygon(((0,0),(0,-1),(-0.7,-0.7)),
             color="blue",alpha=0.9)
L = [[cos(pi*i/4),sin(pi*i/4)] for i in range(8)]
p=polygon2d(L, rgbcolor=(0,0,1),fill=False)
show(p+pn+ne+so+ps+se+sn+sp+es,
     axes=True,fontsize=6,gridlines="minor")
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
show(pn+ne+so+ps+se+sn+sp+es,
     axes=False,fontsize=6,gridlines="minor")
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="grey")
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="red")
show(a+b,figsize=4,fontsize=8,
axes=True,frame=True,aspect_ratio=1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
show(a+b+pn+ne+so+ps+se+sn+sp+es,
     axes=False,fontsize=6,gridlines="minor")
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="black",alpha=1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="red",alpha=1)
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.3)
p2 = polygon(((0,0),(1,2.5),(2.5,1)),
             color="green",alpha=0.3)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.3)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="blue",alpha=0.3)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.3)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="violet",alpha=0.3)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="brown",alpha=0.3)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="orange",alpha=0.3)
r=2/sqrt(n(pi))
cp=line([(-1,-1),(-1,1),(1,1)])
cq=line([(1,1),(1,-1),(-1,-1)])
c0=circle((0,0),1,color="red",alpha=0.5)
c1=circle((-1,0),1,color="white",alpha=0.5)
c2=circle((1,0),1,color="white",alpha=0.5)
c3=circle((0,-1),1,color="white",alpha=0.5)
c4=circle((0,1),1,color="white",alpha=0.5)
show(a+b+pc+p1+p2+p3+p4+p5+p6+p7+p8+c1+cp+\
     cq+c2+c3+c4+c0+pn+ne+so+ps+se+sn+sp+es,
figsize=10,fontsize=8,axes=True,frame=True,gridlines="minor",
gridlinesstyle=dict(color="lightgrey",linestyle="-",alpha=0.3))
# Out:
# Graphics object consisting of 28 graphics primitives

# %%
np = polygon(((0,0),(0,8),(5.7,5.7)),
             color="cyan",alpha=0.5)
gr = polygon(((0,0),(0,8),(-5.7,5.7)),
             color="green",alpha=0.9)
en = polygon(((0,0),(8,0),(5.7,5.7)),
             color="violet",alpha=0.5)
os = polygon(((0,0),(-8,0),(-5.7,-5.7)),
             color="red",alpha=0.9)
sp = polygon(((0,0),(0,-8),(5.7,-5.7)),
             color="lightgreen",alpha=0.9)
ka = polygon(((0,0),(8,0),(5.7,-5.7)),
             color="salmon",alpha=0.9)
ja = polygon(((0,0),(-8,0),(-5.7,5.7)),
             color="yellow",alpha=0.9)
bl = polygon(((0,0),(0,-8),(-5.7,-5.7)),
             color="blue",alpha=0.9)
Lo= [[8*(cos(pi*i/4)),8*(sin(pi*i/4))] 
     for i in range(8)]
p=polygon2d(Lo, rgbcolor=(0,0,1),fill=False)
show(p+np+en+os+sp+se+sn+sp+es+ka+gr+ja+bl+a+b,
     axes=True,fontsize=6,gridlines=False)
# Out:
# Graphics object consisting of 17 graphics primitives

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='grey',fill=sqrt(4-x^2),
fillcolor="black")
xy=circle((0,0),2,color="white")
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="white")
p=polygon2d(Lo, rgbcolor=(1,1,1),fill=False)
show(p+np+en+os+sp+se+sn+sp+es+ka+gr+ja+bl+xy+a+b,
     axes=False,fontsize=6,gridlines=False,figsize=5)
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
show(p+np+en+os+sp+se+sn+sp+es+ka+gr+ja+bl+xy+a+b,
axes=False,fontsize=6,gridlines=False,figsize=5)
# Out:
# Graphics object consisting of 18 graphics primitives
