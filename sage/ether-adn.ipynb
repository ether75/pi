# %% [markdown]
# #####  tel00003954.pdf page 24
#
# On appelle longueur de Bjerrum [Barrat 1996] la distance pour laquelle l’interaction
# électrostatique entre deux charges unités vaut exactement l’agitation thermique.
#
# Par exemple, deux charges de signe opposées en
# solution vont logiquement s’attirer ($l_b$ grand), à moins que l’agitation thermique soit
# suffisante pour arriver à les éloigner ($l_b$ petit).
#
# $l_b=\frac{e^2}{4\pi\epsilon k T}$
#
# Quand on se trouve en face d'une représentation hélicoïdale, on peut tout de suite affirmer que c'est le déroulement d'un cercle ou d'une élipse de 2D en 3D. D'autre part une hélice est déjà une double pale donc pas besoin de parler de double hélice c'est un pléonasme, fréquement répété par les généticiens !
#
# Maintenant on compare la formule de Coulomb avec celle ci-dessus :
#
# $k_c=\frac{1}{4\pi\epsilon}$
#
# On voit que $kT$ correspond à une valeur de $\mu$ extrêmement petite :
#
# $k_c=8987551787 N$
#
# T= 300 K ,eau =80, l=0.7 nm
#
# $c^2= 89875517873681764 m/s$ donc 7 zéros de moins qui correspondent à $\mu
#
# En fait ce ne sont pas des mètres car il ne s'agit pas d'une vitesse mais d'une fréquence angulaire, voir nombre de tours.
#
# La célérité n'est pas un cercle mais une élipse, si c'était un cercle la célérité serait de 3141592458, alors qu'elle n'est que de 299792458, rapport :1.047 (DO5).

# %%
299792458^2
# Out:
# 89875517873681764

# %%
ce=circle((0,0),3.141592653)
show(ce,figsize=3,axes=False)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
el=ellipse((0,0),2.99792458,1)
show(ce+el,fontsize=6,figsize=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
el=ellipse((0,0),2.99792458,1);el
